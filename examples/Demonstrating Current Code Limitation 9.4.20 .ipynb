# %%
import SignalProcessing

# %%
err_file = "/mnt/b/Zhang Lab/Data/NP Encapsulation July 2020/8.6.20/AgNP_Seed_soln_600mV_CFE01_a1b1_8_6_20_end.txt"

# %%
SignalProcessing.peak_detector(err_file, 10, 15, 10)
# Out:
# Total number of detected peaks: 208
#
# Frequency of peaks (Hz): 2.072873254463828
#
# Average peak height (pA): 40.12932211538461 SD: 29.685069358063974
# [208,
#  2.072873254463828,
#  array([ 255623,  361486,  437566,  439418,  439584,  466153,  466185,
#          570163,  570269,  570326,  666234,  685617,  695211,  699816,
#          700436,  700546,  803746,  803749,  844759,  844788,  847664,
#          847666,  848007,  848093,  848178,  848809,  867068,  870007,
#          870867,  900089,  914590, 1000634, 1007870, 1007941, 1008208,
#         1017930, 1044044, 1062588, 1063566, 1103792, 1107376, 1108124,
#         1129671, 1129751, 1134181, 1134267, 1136899, 1137577, 1137581,
#         1153312, 1170644, 1170712, 1203210, 1227120, 1276584, 1281707,
#         1281867, 1281869, 1285172, 1287524, 1288695, 1313524, 1327292,
#         1337338, 1339314, 1397226, 1422309, 1512186, 1512292, 1540789,
#         1547522, 1574102, 1599659, 1614683, 1641295, 1658195, 1680208,
# ...

# %%
SignalProcessing.peak_detector(err_file, 10, 20, 10)
# Out:
# Total number of detected peaks: 122
#
# Frequency of peaks (Hz): 1.2158198896374377
#
# Average peak height (pA): 32.28947950819672 SD: 14.873549252599332
# [122,
#  1.2158198896374377,
#  array([ 361486,  439418,  466185,  570269,  685617,  803746,  803749,
#          844759,  844788,  847664,  847666,  848007,  848093,  848178,
#          867068,  870007,  900089,  914590, 1000634, 1007870, 1062588,
#         1063566, 1107376, 1108124, 1129671, 1129751, 1136899, 1137577,
#         1137581, 1153312, 1203210, 1227120, 1276584, 1287524, 1327292,
#         1337338, 1339314, 1422309, 1512186, 1540789, 1547522, 1574102,
#         1614683, 1680208, 1732172, 1758643, 2065337, 2184812, 2195217,
#         2357149, 2358024, 2408306, 2440045, 2440325, 2448331, 2448595,
#         2621183, 2673769, 2677898, 2699507, 2738796, 2899697, 3158856,
#         3210130, 3243276, 3357076, 3357253, 3525777, 3543265, 3543348,
#         3661098, 3666700, 3773030, 3774787, 3869049, 3870860, 3870920,
# ...

# %%
charges = SignalProcessing.calc_peak_area(err_file, 10, 15, 10)
# Out:
# Total number of detected peaks: 208
#
# Frequency of peaks (Hz): 2.072873254463828
#
# Average peak height (pA): 40.12932211538461 SD: 29.685069358063974
#
# Average peak area (fC): 80.32691225556741 SD: 371.74245902639075

# %%
SignalProcessing.calc_percent_ox(charges, "fC", "Ag", 39.6)
# Out:
# Average estimated particle radius (nm): 9.223421831236006 SD: 5.237055175192626
# Average Percent Oxidation (%): 46.58293854159599 SD: 26.44977361208397
# (array([16.54201321, 10.63635226, 14.0279524 , 13.68075532,  7.22348397,
#          5.31423432, 16.34255812,  8.13445684,  6.38683824,  8.62426122,
#          6.60713281,  7.61692018, 11.1903635 ,  8.4242963 , 18.58134032,
#          5.10072506, 18.64312314, 18.64312314,  9.89625128,  5.73859406,
#          6.66819721,  6.66819721, 10.30463486,  6.14727376, 13.90706586,
#          6.62922368,  8.52660998, 11.23935513,  8.6684483 ,         nan,
#          9.38304791, 11.54683817,  9.92725762,  5.10392451,  6.51415277,
#          8.41719907,  6.04581586,  9.91410625,  6.24351568, 10.02193136,
#          9.51474038,  5.25920885, 10.57227203,  5.53064541,  5.14117   ,
#          9.68094755, 10.85971477,  8.17234027,  8.17234027,  6.03129057,
#         10.84471515,  6.96261538, 11.22633088, 12.23589955,  8.2457521 ,
# ...
